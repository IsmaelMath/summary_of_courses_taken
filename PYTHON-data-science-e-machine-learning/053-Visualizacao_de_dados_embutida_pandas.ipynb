# %% [markdown]
# ### Visualização de dados embutida ao Pandas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use("bmh")# Estilodo gráfico

# %%
df1 = pd.read_csv("/home/quant/Documents/2 - ASIMOV - Python-para-data-science-e-machine-learning/Python-Data-Science-and-Machine-Learning-Bootcamp/3. Python para Visualização de dados/Visualização de dados incorporada do Pandas/df1", ); df1.head(5)
# Out:
#    Unnamed: 0         A         B         C         D
# 0  2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 1  2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2  2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 3  2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 4  2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv("/home/quant/Documents/2 - ASIMOV - Python-para-data-science-e-machine-learning/Python-Data-Science-and-Machine-Learning-Bootcamp/3. Python para Visualização de dados/Visualização de dados incorporada do Pandas/df2"); df2.head(5)
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df3 = pd.read_csv("/home/quant/Documents/2 - ASIMOV - Python-para-data-science-e-machine-learning/Python-Data-Science-and-Machine-Learning-Bootcamp/3. Python para Visualização de dados/Visualização de dados incorporada do Pandas/df3"); df3.head(5)
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
df1["A"].hist(figsize=(6,4))
# Out:
# <AxesSubplot: >

# %%
df2.plot.bar(stacked=True)
# Out:
# <AxesSubplot: >

# %%
df2.plot.area()
# Out:
# <AxesSubplot: >

# %%
df1["A"].plot.hist(bins=50)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
df1.head(5)
# Out:
#    Unnamed: 0         A         B         C         D
# 0  2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 1  2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2  2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 3  2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 4  2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1.columns = ['Date', 'A', 'B', 'C', 'D']
df1["Date"] = pd.to_datetime(df1["Date"]); df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1000 non-null   datetime64[ns]
#  1   A       1000 non-null   float64
#  2   B       1000 non-null   float64
#  3   C       1000 non-null   float64
#  4   D       1000 non-null   float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 39.2 KB

# %%
df1.plot.line(x="Date", y="B", figsize=(12,3), lw=1)
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
df1.plot.scatter(x="A", y="B",c="C", s=df1["C"]*100, cmap="inferno", figsize=(16,6))
# Out:
# /home/quant/.local/lib/python3.10/site-packages/matplotlib/collections.py:967: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <AxesSubplot: xlabel='A', ylabel='B'>

# %%
df1.plot.box()
# Out:
# <AxesSubplot: >

# %%
df = pd.DataFrame(np.random.randn(100,2), columns=["A", "b"]);df
# Out:
#            A         b
# 0   1.097668 -0.073267
# 1   0.493219 -1.871068
# 2   1.110623  0.186026
# 3   3.078798  1.113229
# 4   0.306123  1.007157
# ..       ...       ...
# 95 -2.313365 -0.039393
# 96 -0.852086 -0.031775
# 97  0.135990  2.822827
# 98  0.390823  2.436490
# 99  0.807088  0.164133
#
# [100 rows x 2 columns]

# %%
df.plot.hexbin(x="A", y="b", gridsize=20, cmap="Oranges")
# Out:
# <AxesSubplot: xlabel='A', ylabel='b'>

# %%
df2.plot.kde()
# Out:
# <AxesSubplot: ylabel='Density'>

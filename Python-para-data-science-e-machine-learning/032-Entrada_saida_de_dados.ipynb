# %% [markdown]
# ### Métodos de Entranda e Saída de Dados

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/home/quant/Documents/2 - ASIMOV - Python-para-data-science-e-machine-learning/Python-Data-Science-and-Machine-Learning-Bootcamp/2. Python para análise de dados/Pandas/exemplo"); df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
# Podemos fazer operações com o dataframes
df = df + 1; df
# Out:
#     a   b   c   d
# 0   1   2   3   4
# 1   5   6   7   8
# 2   9  10  11  12
# 3  13  14  15  16

# %%
# Podemos salvar esse arquivo com o método .to_csv("nome_do_arquivo.csv", sep=";", decimal=",")
df.to_csv("nome do arquivo.csv", sep=";", decimal=",")

# %%
# Lendo arquivo do excel
df = pd.read_excel("Exemplo_Excel.xlsx"); df
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
# Usando o métod read_html(), para ler tabela de sites
df = pd.read_html("https://pt.wikipedia.org/wiki/Banco_Central_do_Brasil"); df
# Out:
# [    0                                                  1
#  0 NaN  Esta página cita fontes, mas que não cobrem to...,
#                          Banco Central do Brasil  \
#  0                                           NaN
#  1                                           NaN
#  2   Edifício-sede do Banco Central, em Brasília
#  3                                   Organização
#  4                             Natureza jurídica
#  5                                        Chefia
#  6                                   Localização
#  7                        Jurisdição territorial
#  8                                          Sede
#  9                                     Histórico
#  10                                      Criação
#  11                            Sítio na internet
#  12                               www.bcb.gov.br
#
#                              Banco Central do Brasil.1
#  0                                                 NaN
# ...

# %%
df[2][["Unidade"]]
# Out:
#            Unidade
# 0  Brasília (sede)
# 1            Belém
# 2   Belo Horizonte
# 3         Curitiba
# 4        Fortaleza
# 5     Porto Alegre
# 6           Recife
# 7         Salvador
# 8        São Paulo
# 9   Rio de Janeiro
